# %% [markdown]
# # Abstracto

# %% [markdown]
# ## Introducción

# %% [markdown]
# Me gustaría comenzar un nuevo archivo para la entrega final, para poder diferenciar el proceso de aprendizaje, más que nada para mí. Por lo tanto, voy a traer las mismas secciones que en el anterior, pero analizándolas desde un punto más avanzado, comparado con el anterior.

# %% [markdown]
# ## Elección del dataset

# %% [markdown]
# Me llamó la atención este dataset porque tenía muchas columnas, nunca había trabajado con tantas columnas y menos del estilo de este dataset que es muy categórico y quería saber cómo podía llevarlo a cabo. Y cuando el profe mencionó que este dataset estaba bueno como primera práctica, me cerró por todos lados. No es que me guste particularmente de qué trata, pero me interesa lo suficiente como para intentar comprenderlo y trabajar con él. Realmente mi motivación no cambió mucho a la hora de la elección del dataset, pero buscando otros dataset para clustering y regresión, me di cuenta que este dataset no solo está muy completo, sino que aparte, tiene la limpieza y transformación de los datos muy bien hecha (lo cual ahorra mucho tiempo de trabajo).

# %% [markdown]
# ## Planteo de hipótesis

# %% [markdown]
# Esta parte es la que más cambió. Escuché los consejos de la pre-entrega y voy a decantarme por una de las opciones que fueron mencionadas en la corrección, que sería: "La edad de ingreso está directamente vinculada con el rendimiento (egreso) académico". Esta está vinculada fuertemente con mis primeras intenciones cuando vi el dataset. En cambio, mi segunda hipótesis sale de lo que había planeado y realmente en la pre-entrega no la había tomado en cuenta porque no entendía totalmente a qué hacía referencia los curricular units. Se me ocurrió ver e intenté relacionar el hecho de si se superaba cierto número de inscripciones había cierto % de que abandone, pero realmente no me cerró del todo y no se me ocurre cómo ver eso con gráficos, así que decidí optar por "Semestres inscriptos y desaprobados por género". También tomé en cuenta las personas que se movilizaron o dejaron cosas atrás, ya que entiendo que es una motivación muy grande y debe de haber un impacto en su rendimiento, el género es relevante, esta hipótesis está por más curiosidad que otra cosa, pero en caso de obtener un resultado se puede aplicar muy fácilmente en acciones para solucionarlo.

# %% [markdown]
# ### Hipótesis
# H1: La edad de ingreso está directamente vinculada con el rendimiento académico.
#
# H2: Existe una relación entre los semestres inscriptos y los aprobados basada en el resultado académico.
#
# H3: Los estudiantes desplazados (displaced) tienden a obtener mejores resultados académicos.
#
# H4: El género impacta en el resultado académico final.
#
# H5: Los estudiantes internacionales (international) tienden a registrar un peor rendimiento académico.
#
# H6: Los estudiantes becados tienden a demostrar un mejor rendimiento académico.

# %% [markdown]
# ## Contextualización

# %% [markdown]
# Antes de hablar del objetivo, me gustaría establecer un contexto para ayudarme a entender el porqué de las acciones. La situación es esta: la universidad tiene la intención de hacer una campaña para aumentar el número de graduados pero no sabe dónde comenzar. Ahí es donde entramos nosotros, debemos comprender y ayudar a esta universidad a identificar un punto débil (si puede llamarse así) para que pueda enfocar esta campaña y esta dé sus frutos. Podríamos agregar de dónde recibimos los datos, tengo entendido que es lo que también afecta el proceso de limpieza y en este caso, diremos que lo recibimos en formato CSV.

# %% [markdown]
# ### Variables objetivos.
# Nuestra variable principal (Target) es la cual nos dice si la persona abandonó, sigue en curso o se graduó. Lo primero que hacemos es cambiar la variable de multiclase a binaria, lo dividimos por si abandonó o no abandonó. Posterior a hacer esto me di cuenta que el agrupar las variables de esta manera no nos dicen que si la persona no abandonó significa que vaya a graduarse, pero es algo que tenemos en cuenta, ya que nuestro objetivo es evitar que se vayan y que potencialmente se gradúen, pero no buscamos específicamente que se gradúen (solo quería aclararlo). Nuestro objetivo, entonces, es predecir este comportamiento con otras variables que cumplan con nuestra hipótesis, por lo tanto, las variables que vamos a utilizar son: Gender (género), Age at enrollment (Edad), Curricular units 1st sem (enrolled) (Las materias a las cuales se inscribió en el primer semestre), Curricular units 1st sem (approved) (Las materias que aprobó en el primer semestre), Curricular units 2nd sem (enrolled) (Materias a las cuales se inscribió en el segundo semestre), Curricular units 2nd sem (approved) (Materias a las cuales aprobó en el segundo semestre), también utilizaremos si tiene una beca (scholarship holder), utilizaremos Displaced (muestra si el alumno/a) tuvo que moverse de su ciudad o pueblo natal para estudiar, y por último, utilizaremos International (nos dice si viene de otro país o no) (más adelante explico que está sujeto a cambios).
# ### Variables no tomadas.
# Decidí no tomar las variables relacionadas a la economía del país (Unemployment rate, Inflation rate, GDP) porque pensando cómo utilizarlas se me extendía mucho el impacto y siento que va a faltar, o no voy a ser capaz de extraer todo su valor. Variables académicas restantes (Curricular units 2nd sem (credited), Curricular units 2nd sem (evaluations), Curricular units 2nd sem (grade), Curricular units 2nd sem (without evaluations) y Curricular units 1st sem (without evaluations), Curricular units 1st sem (grade), Curricular units 1st sem (evaluations), Curricular units 1st sem (credited)) me parece que salen del alcance del análisis, no es lo que estoy buscando, se aperturan demasiado. De los factores socioeconómicos y familiares (Tuition fees up to date, Debtor, Educational special needs, Mother's occupation / Father's occupation, Mother's qualification / Father's qualification, Daytime/evening attendance) creo que no forma parte de lo que busco predecir, podrían aportar valor pero si me estuviese apoyando en el entorno social y el análisis no lo está tomando en cuenta como algo principal ya que es muy complejo de dimensionar. Antecedentes académicos (Application mode, Application order, Course, Previous qualification, Previous qualification (grade)) creo que son interesantes pero no creo que sean completamente relevantes ya que hay otras variables que aportan mucho más valor. Datos sociodemográficos (Marital status) solo saqué este porque no lo veo "relevante", más que nada creo que no puedo sacarle tanto valor. Esté análisis esta sujeto a cambios.

# %% [markdown]
# ## Diccionario

# %% [markdown]
# Esta parte sirve para aclarar y que se puedan entender un poco más los datos y que representan.
#
# Age at enrollment: Edad en la cual se inscribieron a la universidad(Integer).
# Gender: Género de la persona {1 = male, 0 = female}(Integer).
# Target: La persona abandonó {0 = yes, 1 = no)}(Integer)
# Curricular units 1st sem(enrolled): Materias a las que se inscribió en el primer semestre.(Integer)
# Curricular units 1st sem(approved): Materias a las que aprobó en el primer semestre.(Integer)
# Curricular units 2nd sem(enrolled): Materias a las que se inscribió en el segundo semestre.(Integer)
# Curricular units 2nd sem(approved): Materias a las que aprobó en el segundo semestre.(Integer)
# Scholarship holder: Si tiene o no beca {1 = yes, 0 = no}(Integer)
# Displaced: La persona tuvo que desplazarse para poder asistir a la universidad {1 = yes,  0 = no}(Integer)
# International: Nos dice si el alumno es extranjero {1 = yes, 0 = no}(Integer)

# %% [markdown]
# # Análisis exploratorio de los datos

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report

# %%
def add_jitter(arr, amount=0.2):
    return arr + np.random.normal(0, amount, size=len(arr))
    #según lo que encontre, esta función es para evitar que los enteros se solapen y se tapen unos a otros.
    #Siguiendo esta lógica, pensé que tal vez eso sesgaría el modelo, pero me ayuda mucho a entender y confirmar
    #lo que pensaba del comportamiento de estas variables(columnas).

# %%
SEED = 38

# %%
df = pd.read_csv("coderhouse/Data Science I/Dropout.csv", sep =";")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4424 entries, 0 to 4423
# Data columns (total 37 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Marital status                                  4424 non-null   int64
#  1   Application mode                                4424 non-null   int64
#  2   Application order                               4424 non-null   int64
#  3   Course                                          4424 non-null   int64
#  4   Daytime/evening attendance	                     4424 non-null   int64
#  5   Previous qualification                          4424 non-null   int64
#  6   Previous qualification (grade)                  4424 non-null   float64
#  7   Nacionality                                     4424 non-null   int64
#  8   Mother's qualification                          4424 non-null   int64
# ...

# %% [markdown]
# ### Conclusión
# Podemos ver que todos los valores menos uno son todos númericos. Esto es muy bueno a la hora de encarar la preparación de los datos para entrenar. Yo pensaba que ese Object podía pasarse a encoders, pero resulta que es una de decirnos que los datos númericos vinieron mal. Por lo tanto, siguiendo la regla de la realidad, no los procesamos porque no los utilizamos y nos ahorramos el tiempo de procesado.

# %%
df.isna().sum()
# Out:
# Marital status                                    0
# Application mode                                  0
# Application order                                 0
# Course                                            0
# Daytime/evening attendance\t                      0
# Previous qualification                            0
# Previous qualification (grade)                    0
# Nacionality                                       0
# Mother's qualification                            0
# Father's qualification                            0
# Mother's occupation                               0
# Father's occupation                               0
# Admission grade                                   0
# Displaced                                         0
# Educational special needs                         0
# Debtor                                            0
# Tuition fees up to date                           0
# Gender                                            0
# ...

# %% [markdown]
# ### Conclusión
# Podemos ver que no existen valores nulos en nuestro dataset.

# %%
df.describe()
# Out:
#        Marital status  Application mode  Application order       Course  \
# count     4424.000000       4424.000000        4424.000000  4424.000000
# mean         1.178571         18.669078           1.727848  8856.642631
# std          0.605747         17.484682           1.313793  2063.566416
# min          1.000000          1.000000           0.000000    33.000000
# 25%          1.000000          1.000000           1.000000  9085.000000
# 50%          1.000000         17.000000           1.000000  9238.000000
# 75%          1.000000         39.000000           2.000000  9556.000000
# max          6.000000         57.000000           9.000000  9991.000000
#
#        Daytime/evening attendance\t  Previous qualification  \
# count                   4424.000000             4424.000000
# mean                       0.890823                4.577758
# std                        0.311897               10.216592
# min                        0.000000                1.000000
# ...

# %% [markdown]
# ### Conclusión
# Podemos ver que existe la presencia de valores atípicos(outliers), ya que el max se aleja muchisimo del 75% de los datos en el análisis de los intercuartiles, en casos de los curricular units, la idea es ver si esos datos son errores, inputs equivocados o solamente valores que exceden la media por mucho.

# %%
df.head()
# Out:
#    Marital status  Application mode  Application order  Course  \
# 0               1                17                  5     171
# 1               1                15                  1    9254
# 2               1                 1                  5    9070
# 3               1                17                  2    9773
# 4               2                39                  1    8014
#
#    Daytime/evening attendance\t  Previous qualification  \
# 0                             1                       1
# 1                             1                       1
# 2                             1                       1
# 3                             1                       1
# 4                             0                       1
#
#    Previous qualification (grade)  Nacionality  Mother's qualification  \
# 0                           122.0            1                      19
# 1                           160.0            1                       1
# ...

# %% [markdown]
# Hice el head aca abajo, para poder ver los valores mientras aplicaba algunos cambios.

# %%
df['Target'] = df['Target'].replace({2: 1}) #reemplazamos los valores 2 a 1 que ahora representan que: no abandonó, mientras que el 0 sigue representando el dropout

# %%
df['Target'].value_counts(normalize = True) * 100 #Acá vemos como el ratio de los que no abandonaron es  casi tres veces mayor que los que abandonaron. Igualmente vamos hacer un gráfico sobre ello
# Out:
# Target
# 1    67.879747
# 0    32.120253
# Name: proportion, dtype: float64

# %% [markdown]
# ### Gráficos de valor

# %%
plt.figure(figsize =(12,6))
counts = df["Target"].replace({
    0: "Abandonó (Dropout)",
    1: "Graduado / En curso"
}).value_counts()
counts.plot(
    kind="pie",
    autopct="%1.1f%%",
    labels=None,
    startangle=90,
    colors=['#ff9999', '#66b3ff'] 
)
plt.legend(
    counts.index, 
    title="Estado académico",
    loc="center left",
    bbox_to_anchor=(1, 0.5)
)
plt.ylabel("")
plt.title("Distribución de alumnos x Estado Académico")

plt.show()

# %%
## La ia me ayudo con los colores, se que es un poco redundante pero para prácticar los gráficos, sirve.

# %%
plt.figure(figsize =(12,6))
df["Gender"].replace({
    0:"Male",
    1:"Female"
}).value_counts().plot(
    kind="pie",
    autopct="%1.1f%%",
    labels=None,
    startangle=90,
    colors=['#66b3ff', '#ff9999'], 
)

plt.legend(
   ["Hombre", "Mujer"],
    title="Género",
    loc="center left",
    bbox_to_anchor=(1,0.5)
)

plt.ylabel("")
plt.title("Distribución de alumnos x género")

plt.show()

# %%
# Me traigo este gráfico más que nada para mostrar que la proporción de hombres es casi el doble que el de mujeres, lo cual resulta relevante para futuros análisis

# %%
plt.figure(figsize =(12,6))

sns.countplot(
    data=df, 
    x="Target", 
    hue="Gender", 
    palette=['#ff9999', '#66b3ff'] 
)

plt.title("Cantidad de dropouts y graduados/en curso por género")
plt.xlabel("Estado académico")
plt.ylabel("Cantidad")

plt.xticks(
    ticks=[0, 1], 
    labels=["Abandonó", "Graduado / En curso"] 
)

plt.legend(
    title="Género",
    labels=["Hombre", "Mujer"]
)

plt.show()

# %% [markdown]
# ### Conclusión
# Al entender que los hombres son casi el doble de las mujeres podemos entender de este gráfico que mujeres y hombres tienen una tasa de no abandono similar,  mientras que la de abandono(debido a la diferencia de la proporción), nos dice que los hombres tienden a abandonar menos.

# %%
df['Estado Académico'] = df['Target'].map({
    0: 'Abandonó (Dropout)', 
    1: 'Graduado / En curso'
})
plt.figure(figsize=(12, 6))
sns.histplot(
    data=df, 
    x="Age at enrollment", 
    hue="Estado Académico",
    multiple="stack",
    bins=30,          
    kde=True,         
    palette=['#66b3ff', '#ff9999']
)
plt.title("Distribución de Edad al momento de inscripción por Estado Académico")
plt.xlabel("Edad al inscribirse (Age at enrollment)")
plt.ylabel("Cantidad de alumnos")
plt.show()

# %% [markdown]
# ### Conclusión
# Acá podemos apreciar la presencia de valores atípicos(como la presencia de una persona de 70 años), también podemos observar que los valores más grandes de abandono suceden entre los 18 y 22 años. Aunque viendolo así parece que hay más abandonó que graduado y en curso y nuestros números lo desmienten. Así que voy a probar con otro gráfico que pueda mostrar mejor las cosas(dejo este porque me parece un buen descubrimiento).

# %%
df['Estado Académico'] = df['Target'].map({0: 'Abandonó (Dropout)', 1: 'Graduado / En curso'})
plt.figure(figsize=(12, 6))
sns.histplot(
    data=df, 
    x="Age at enrollment", 
    hue="Estado Académico", 
    multiple="dodge", 
    bins=30,          
    kde=True,         
    palette=['#66b3ff', '#ff9999']
)
plt.title("Graduados vs Abandonos por Edad")
plt.xlabel("Edad al inscribirse")
plt.ylabel("Cantidad real de alumnos")
plt.show()

# %% [markdown]
# ### Conclusión
# En este se puede apreciar claramente la diferencia de valores, y acá podemos apreciar que a partir de los 25/26 años, la tasa de abandonó comienza a superar a la tasa de graduados.
# Los gráficos fueron con ayuda de la IA.

# %%
columnas = [
    "Curricular units 1st sem (enrolled)", 
    "Curricular units 1st sem (approved)", 
    "Curricular units 2nd sem (enrolled)", 
    "Curricular units 2nd sem (approved)"
]
plt.figure(figsize=(14, 8))
sns.boxplot(data=df[columnas], palette="Set3")

plt.title("Distribución de Unidades Curriculares (Inscritas vs Aprobadas)")
plt.ylabel("Cantidad de Materias")
plt.xticks(rotation=15)

plt.show()

# %% [markdown]
# ### Conclusión
# Acá podemos ver claramente la presencia de valores atípicos y podemos ver claramente que el promedio de las materias inscriptas en ambos semestres es de 6 mientras que las materias aprobadas, baja la mediana y el promedio de aprobadas en ambos semestres disminuye a 5. Gracias a esto podemos entender un poco más como se comporta esta variable.

# %% [markdown]
# Bueno, lo que sigue acá es una maravilla de la IA para mostrar un scattrplot, que cuando pensé en las columnas de materias aprobadas e inscriptas por semestre, instantáneamente pensé en un scatterplot, pero estuve intentando y no lo podía hacer. Entonces, le pregunte a la IA por mejoras, me dio este pedazo de gráfico y no lo podía dejar afuera.

# %%
plt.figure(figsize=(10, 8))
sns.scatterplot(
    x=add_jitter(df["Curricular units 1st sem (enrolled)"]), 
    y=add_jitter(df["Curricular units 1st sem (approved)"]), 
    hue=df["Estado Académico"], 
    palette=['#66b3ff', '#ff9999'],
    alpha=0.6,
    edgecolor=None
)
plt.plot([0, 26], [0, 26], color='gray', linestyle='--', linewidth=1.5, alpha=0.7, label='Aprobó el 100%')
plt.title("Relación de Materias Inscritas vs Aprobadas (1er Semestre)")
plt.xlabel("Materias Inscritas (1er Semestre)")
plt.ylabel("Materias Aprobadas (1er Semestre)")
plt.legend()
plt.show()

# %% [markdown]
# ### Conclusión
# Como creía, cuanta menor cantidad de materias aprobadas en base a las aplicadas, mayor chance hay de abandonar. En este caso vemos como la mayoría se concentra entre las 4 y 7 materias inscriptas y si no aprueban mas de 3 tienden a abandonar.

# %%
plt.figure(figsize=(10, 8))
sns.scatterplot(
    x=add_jitter(df["Curricular units 2nd sem (enrolled)"]), 
    y=add_jitter(df["Curricular units 2nd sem (approved)"]), 
    hue=df["Estado Académico"], 
    palette=['#66b3ff', '#ff9999'],
    alpha=0.6,
    edgecolor=None
)
plt.plot([0, 26], [0, 26], color='gray', linestyle='--', linewidth=1.5, alpha=0.7, label='Aprobó el 100%')

plt.title("Relación de Materias Inscritas vs Aprobadas (2do Semestre)")
plt.xlabel("Materias Inscritas (2do Semestre)")
plt.ylabel("Materias Aprobadas (2do Semestre)")
plt.legend()

plt.show()

# %% [markdown]
# ### Conclusión
# Como podemos observar vemos un comportamiento muy similar al anterior, respentando lo que habíamos planteado anteriormente. Viendo esto así se me ocurrió que tal vez podríamos estar pasando desapercibido el hecho de la diferencia entre el primero y segundo semestre, pero como no tenemos el hecho de cuando abandonó es algo que vamos a tener que aceptar y avanzar.

# %%
df['International'].value_counts(normalize = True) * 100 
#Como podemos ver aca hay un 97 % de personas que no son International, por lo tanto dejo de lado esta columna
# Out:
# International
# 0    97.513562
# 1     2.486438
# Name: proportion, dtype: float64

# %%
df['Displaced'].value_counts(normalize = True) * 100
# Por su parte Displaced tiene una mejor distribución así que voy con esta.
# Pense en ver esto porque los International son todos Displaced pero no todos los Displaced
# son international, había pensado en unirlos, pero ahora veo que es más trabajo que recompensa.
# Out:
# Displaced
# 1    54.837251
# 0    45.162749
# Name: proportion, dtype: float64

# %%
df['Desplazado'] = df['Displaced'].map({1: 'Sí', 0: 'No'})
plt.figure(figsize=(8, 6))
sns.countplot(
    data=df, 
    x='Desplazado', 
    hue='Estado Académico', 
    palette=['#66b3ff', '#ff9999']
)
plt.title('Impacto de ser Desplazado en el Estado Académico')
plt.xlabel('¿Es desplazado? (Se mudó para estudiar)')
plt.ylabel('Cantidad de alumnos')

plt.show()

# %% [markdown]
# ### Conclusión
# Podemos ver que hay más graduados antes que abandono. Pero lo que nos importa es que hay menos abandono en las personas que se mudaron para estudiar. Creo que esta variable es relevante porque tenemos más de un 50% de los alumnos que se mudan para estudiar. Me gustaría saber si mantiene alguna relación con si tienen o no una beca.

# %%
df['Scholarship holder'].value_counts(normalize = True) * 100
# Podemos notar que 1 entre 3 tiene beca(lo cuál es un montón).
# Out:
# Scholarship holder
# 0    75.158228
# 1    24.841772
# Name: proportion, dtype: float64

# %%
df['Becado'] = df['Scholarship holder'].map({1: 'Sí', 0: 'No'})

plt.figure(figsize=(8, 6))
sns.countplot(
    data=df, 
    x='Becado', 
    hue='Estado Académico', 
    palette=['#66b3ff', '#ff9999']
)
plt.title('Impacto de tener Beca en el Estado Académico')
plt.xlabel('¿Es titular de una beca? (Scholarship holder)')
plt.ylabel('Cantidad de alumnos')

plt.show()

# %% [markdown]
# ### Conclusión
# Podemos ver claramente y confirmar que de ese 1/3 de alumnos con beca, la mayoría de ellos tienden a graduarse. Podemos sacar que es extremadamente raro que las personas con becas abandonen la carrera. Esto es una ocurrencia extra, pero asumo que los que abandonaron la carrera a pesar de tener beca, se debe a una mala situación economica pero no estamos analizando eso ahora.

# %% [markdown]
# Esto me di cuenta después de haber hecho los gráficos y si bien hay muchas variables que no aportan tanto al modelo, creo que hay algunas que no tuve en cuenta y voy a analizar porque creo que pueden llegar a impactar en la predicción

# %%
df['Estado Académico'] = df['Target'].map({
    0: 'Abandonó (Dropout)', 
    1: 'Graduado / En curso'
})

plt.figure(figsize=(12, 6))

sns.histplot(
    data=df, 
    x="Admission grade", 
    hue="Estado Académico", 
    kde=True,               
    element="step",         
    palette=['#66b3ff', '#ff9999'], 
    alpha=0.6               
)

plt.title("Distribución de Notas de Admisión: Graduados vs Dropouts", fontsize=14)
plt.xlabel("Nota de Admisión (Admission grade)", fontsize=12)
plt.ylabel("Cantidad de Estudiantes", fontsize=12)

plt.show()

# %% [markdown]
# ### Conclusión
# Podemos ver la presencia de valores atípicos y si bien hay un parte del gráfico que nos dice que entre 0 y 105 hay mas chance de que abandone antes de que continue o se gradúe, no podemos afirmar que sea una variable decisiva a la hora de abandonar, porque el pico de ambos se concentra en valores intermedios. No creo que sea determinante pero tampoco irrelevante.

# %% [markdown]
# Otra que analizo más que nada por curiosidad, realmente el orden de prioridad en la que aplico a las universidades puede modificar el resultado académico?

# %%
plt.figure(figsize=(12, 6))

sns.countplot(
    data=df, 
    x="Application order", 
    hue="Estado Académico",         
    palette=['#ff9999', '#66b3ff']  
)
plt.title("Distribución del Orden de Aplicación según Estado Académico", fontsize=14)
plt.xlabel("Orden de Aplicación (1 = Primera opción, 2 = Segunda, etc.)", fontsize=12)
plt.ylabel("Cantidad de Estudiantes", fontsize=12)

plt.show()

# %% [markdown]
# ### Conclusión
# Al final, pasó lo que sospechaba, este gráfico no nos dice mucho ya que se mantiene acorde a la proporción y no podemos afirmar que sea determinante o afecte de alguna u otra manera a la variable objetivo. Práctimente todos se mantiene en el 1/3, 2/3 como nos dicta la proporción de graduados. Lo que podemos observar es que a pesar de ser la primera opción de los alumnos, se concentran allí la mayoría de los Dropout y superan un poco la proporción. Aunque cabe recalcar que no sabemos el prestigio de la universidad, tal vez es una con un alto porcentaje de aceptación pero no tenemos los datos de ello.

# %% [markdown]
# Al final me rendí a la variables economicas, porque pensando en frío, realmente es una variable muy importante, sobre todo por las edades que manejamos.

# %%
plt.figure(figsize=(10, 6))

sns.boxplot(
    data=df, 
    x="Estado Académico", 
    y="Unemployment rate", 
    palette=['#66b3ff', '#ff9999']
)

plt.title("Distribución de la Tasa de Desempleo según Estado Académico", fontsize=14)
plt.xlabel("Estado Académico", fontsize=12)
plt.ylabel("Tasa de Desempleo (%)", fontsize=12)

plt.show()
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_25868\535404260.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(

# %% [markdown]
# ### Conclusión
# Podemos ver que la tasa de desempleo no afecta directamente en el rendimiento académico, pero teniendo en cuenta que nuestras edades promedio de abandonar esan entre los 18 y 23 años, hay un % menor de jóvenes con trabajo a esa edad que a una edad avanzada. Como dije en la preparación de los datos y variables a utilizar, es una variable compleja creo, tal vez hay más contexto del cuál no me estoy dando cuenta. Así que ya que el porcentaje de desempleo creo que no afecta debido a la edad, me imagino que los encargados de pagar serían los padres, pero no tenemos salario o algo parecido así que vamos a pasar simplemente a si esta o no esta pago(Tuition fees up to date).

# %%
plt.figure(figsize=(10, 6))

sns.countplot(
    data=df, 
    x="Tuition fees up to date", 
    hue="Estado Académico", 
    palette=['#ff9999', '#66b3ff']
)
plt.title("Impacto del pago de cuotas en la Retención Estudiantil", fontsize=14)
plt.xticks(ticks=[0, 1], labels=["Atrasado (0)", "Al día (1)"]) 
plt.xlabel("Estado de las Cuotas (Tuition fees up to date)", fontsize=12)
plt.ylabel("Cantidad de Estudiantes", fontsize=12)
plt.show()

# %% [markdown]
# ### Conclusión
# En cambio en este, me sorprendió, nos muestra que a pesar de haber casi tres veces mas graduados en general, si el alumno/A no esta al día con sus cuotas hay 4 veces más chances de que abandoné. Muy relevante

# %%
plt.figure(figsize=(12, 6))

sns.kdeplot(
    data=df, 
    x="Admission grade", 
    hue="Estado Académico", 
    fill=True,              
    common_norm=False,       
    palette=['#66b3ff', '#ff9999'], 
    alpha=0.5,               
    linewidth=2              
)

plt.title("Distribución de Notas de Admisión: Curvas de Densidad", fontsize=14)
plt.xlabel("Nota de Admisión (Admission grade)", fontsize=12)
plt.ylabel("Densidad (Concentración de estudiantes)", fontsize=12)

plt.show()

# %% [markdown]
# ### Conclusión
# Podemos ver que hasta 120(nota) la densidad de personas que abandonan es superior a las que no abandonan. Por lo tanto nos muestra un comportamiento relevante para la variable objetivo.

# %% [markdown]
# ## Conclusiones del EDA
# Lo principal a recalcar es que hay casi 1/3 de estudiantes que dejan la carrera en la cual estaban inscriptos. Luego con relación a lo que analizamos, decidí cambiar mi enfoque a los datos que había pensado utilizar, debido a que me parecían insuficientes, a medidad que avanzaba me di cuenta que debía tomar más datos y que habían datos que no tome en cuenta al principio pero que durante el análisis se mostraron más útiles de lo predicho. Por eso dejo la primera parte del abstracto donde mencionó cuáles no utilizo. Para aclarar las variables que termine utilizando son: Marital status, Application order, Admission grade, Displaced, Educational special needs, Debtor, Tuition fees up to date, Gender, Scholarship holder, Age at enrollment, International, Curricular units 1st sem (enrolled), Curricular units 1st sem (approved), Curricular units 2nd sem (enrolled), Curricular units 2nd sem (approved). Debo agregar que la IA para generar los gráficos es increiblemente útil, sobre todo para las parte de las leyendas y los textos, quería saber que tan buena o mala práctica es el hecho de que me haya creado nuevas columnas para mostrar los gráficos, en la práctica me resulto muy útil y tuve cuidado en sacarlas del análisis del modelo.
#
# Lo más relevante del análisis es que identificamos que la principal causa de abandonó es por reprobar más de la mitad de las materias a las cuáles se habían inscripto tanto en el primer como en el segundo semestre. También entendimos que el hecho de no tener las cuaotas al día es relevante a la hora de abandonar o no hacerlo. Si bien es verdad que, por ejemplo la variable age at enrollment, muestra que mayor edad, mayor chance de abandonó, el hecho de que el promedio de edad se encuentre en edades más jovenes minimiza el impacto en la variable Target.
#
# Descubrimos que la variable Gender no afecta directamente a la variable a predecir y que si bien hay una diferencia principalmente en la tasa de abandonó, la variable objetivo no se ve afectada. Nos dimos cuenta que la proporción de alumnos extranjeros es tan ínfima que no creo que afecte en el resultado de la variable objetivo. También vimos que unemployment rate no afecta de manera directa a nuestra variable a predecir, pero cabe recalcar que no estamos orientados a verla, porque podríamos buscar por los alumnos que estudian a la noche y ahí analizar la misma variable y probablemente cambie el resultado o un segmento de edad más avanzado, pasaría lo mismo.
#
# Pudimos identificar que el hecho de que los alumnos se muden para poder estudiar afecta positivamente en su resultado académico, si bien no es tan relevante como las materias aprobadas, es importante mencionarlas.
#
# Por último quiero recalcar que utilizaremos muchas variables para el análisis predictivo con árboles de decisión y incluiremos algunas que sin bien no tienen un impacto directo tan notable, son importantes para mantener la relación con otras variables. Sin embargo variables como Unemployment rate no van a ser tomadas en cuenta por la características de los datos, si bien es una variable que es muy relevante, debido a esta concentración en edades no la podemos utilizar y sacarle el mayor provecho.

# %% [markdown]
# # Procesamiento de Conjuntos

# %%
df.columns
# Out:
# Index(['Marital status', 'Application mode', 'Application order', 'Course',
#        'Daytime/evening attendance\t', 'Previous qualification',
#        'Previous qualification (grade)', 'Nacionality',
#        'Mother's qualification', 'Father's qualification',
#        'Mother's occupation', 'Father's occupation', 'Admission grade',
#        'Displaced', 'Educational special needs', 'Debtor',
#        'Tuition fees up to date', 'Gender', 'Scholarship holder',
#        'Age at enrollment', 'International',
#        'Curricular units 1st sem (credited)',
#        'Curricular units 1st sem (enrolled)',
#        'Curricular units 1st sem (evaluations)',
#        'Curricular units 1st sem (approved)',
#        'Curricular units 1st sem (grade)',
#        'Curricular units 1st sem (without evaluations)',
#        'Curricular units 2nd sem (credited)',
#        'Curricular units 2nd sem (enrolled)',
#        'Curricular units 2nd sem (evaluations)',
# ...

# %%
X = df.drop(columns=
            ['Application mode', 'Course', 'Daytime/evening attendance\t', 'Previous qualification', 'Previous qualification (grade)', 'Nacionality',
             "Mother's qualification", "Father's qualification","Mother's occupation", "Father's occupation",
             'Curricular units 1st sem (credited)','Curricular units 1st sem (evaluations)', 'Curricular units 1st sem (grade)',  'Curricular units 1st sem (without evaluations)',
              'Curricular units 2nd sem (credited)', 'Curricular units 2nd sem (evaluations)',
             'Curricular units 2nd sem (grade)','Curricular units 2nd sem (without evaluations)', 'Unemployment rate',
             'Inflation rate', 'GDP', 'Target',"Estado Académico", "Becado", "Desplazado"
            ])
y = df["Target"]
#Hacemos la división que vimos en clase!

# %% [markdown]
# Bueno, elimino algunas de las variables que cree para poder mostrar mejor los gráficos, incluyo algunas que no impactan directamente pero creo que si indirectamente, agrego algunas que no fueron analizadas en profundidad como marital status, Educational special needs para darle más información al modelo y ayudarlo a encontrar más patrones, otras como debtor e International estan muy relacionadas a variables ya vistas y sirven para ayudar al modelo con esas relaciones.

# %%
X
# Out:
#       Marital status  Application order  Admission grade  Displaced  \
# 0                  1                  5            127.3          1
# 1                  1                  1            142.5          1
# 2                  1                  5            124.8          1
# 3                  1                  2            119.6          1
# 4                  2                  1            141.5          0
# ...              ...                ...              ...        ...
# 4419               1                  6            122.2          0
# 4420               1                  2            119.0          1
# 4421               1                  1            149.5          1
# 4422               1                  1            153.8          1
# 4423               1                  1            152.0          1
#
#       Educational special needs  Debtor  Tuition fees up to date  Gender  \
# 0                             0       0                        1       1
# ...

# %%
y
# Out:
# 0       0
# 1       1
# 2       0
# 3       1
# 4       1
#        ..
# 4419    1
# 4420    0
# 4421    0
# 4422    1
# 4423    1
# Name: Target, Length: 4424, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3,random_state = SEED,stratify = y)

# %%
X_test
# Out:
#       Marital status  Application order  Admission grade  Displaced  \
# 2712               1                  2            117.8          0
# 3027               1                  4            119.6          1
# 3782               1                  2            119.4          1
# 3321               1                  6            134.3          0
# 2439               1                  1            111.6          0
# ...              ...                ...              ...        ...
# 2605               2                  1            160.0          0
# 2421               2                  1            111.9          1
# 3543               1                  1            122.5          0
# 2296               1                  2            100.0          1
# 1033               1                  1            118.2          1
#
#       Educational special needs  Debtor  Tuition fees up to date  Gender  \
# 2712                          0       1                        1       0
# ...

# %%
y_test
# Out:
# 2712    0
# 3027    0
# 3782    1
# 3321    0
# 2439    0
#        ..
# 2605    1
# 2421    0
# 3543    1
# 2296    0
# 1033    1
# Name: Target, Length: 1328, dtype: int64

# %%
X_train.info()#Comprobamos que sean todos números(float o int) o booleanos
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3096 entries, 3014 to 3397
# Data columns (total 15 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Marital status                       3096 non-null   int64
#  1   Application order                    3096 non-null   int64
#  2   Admission grade                      3096 non-null   float64
#  3   Displaced                            3096 non-null   int64
#  4   Educational special needs            3096 non-null   int64
#  5   Debtor                               3096 non-null   int64
#  6   Tuition fees up to date              3096 non-null   int64
#  7   Gender                               3096 non-null   int64
#  8   Scholarship holder                   3096 non-null   int64
#  9   Age at enrollment                    3096 non-null   int64
#  10  International                        3096 non-null   int64
# ...

# %% [markdown]
# ### Aclaración
# Me acabo de dar cuenta que no tengo ninguna variable posible en el dataset para usar encoders, así que no puedo hacer ese paso.

# %% [markdown]
# # Árbol de decisión

# %%
clf = DecisionTreeClassifier(max_depth = 4, random_state= SEED)
#Traemos el modelo y le asignamos la seed y la máxima cantidad de "capas"

# %%
clf
# Out:
# DecisionTreeClassifier(max_depth=4, random_state=38)

# %%
# %%time
clf.fit(X_train, y_train)#Lo entrenamos
# Out:
# CPU times: total: 0 ns
# Wall time: 4.22 ms
# DecisionTreeClassifier(max_depth=4, random_state=38)

# %%
# %%time
train_pred = clf.predict(X_train)
test_pred = clf.predict(X_test)
# Out:
# CPU times: total: 0 ns
# Wall time: 1.78 ms

# %%
train_pred #vemos los datos del train
# Out:
# array([0, 1, 1, ..., 1, 1, 1], shape=(3096,))

# %%
test_pred #vemos los datos del test
# Out:
# array([0, 1, 1, ..., 0, 0, 1], shape=(1328,))

# %%
print("Train")
print(classification_report(y_train, train_pred))
print("Test")
print(classification_report(y_test, test_pred))
#Mostramos el reporte para ver el rendimiento del modelo
# Out:
# Train
#               precision    recall  f1-score   support
#
#            0       0.86      0.72      0.78       994
#            1       0.88      0.94      0.91      2102
#
#     accuracy                           0.87      3096
#    macro avg       0.87      0.83      0.84      3096
# weighted avg       0.87      0.87      0.87      3096
#
# Test
#               precision    recall  f1-score   support
#
#            0       0.87      0.70      0.78       427
#            1       0.87      0.95      0.91       901
#
#     accuracy                           0.87      1328
#    macro avg       0.87      0.83      0.84      1328
# weighted avg       0.87      0.87      0.87      1328

# %% [markdown]
# ### Conclusión
# Ahí esta fiiteando bastante bien, antes había probado con números superiores y overfitteaba mucho, ahora no esta perfecto, pero encontre un punto mucho más útil. Cabe recalcar que tengo muy pocos datos.
